# %%
import cv2
from yolo_prediction import YOLO_Pred

# %%
yolo=YOLO_Pred('./Model/weights/best.onnx','data.yaml')

# %%
img =cv2.imread('./sample5.jpg')
cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#prediction
img_pred=yolo.prediction(img)

# %%
cv2.imshow('prediction image',img_pred)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import yaml
from yaml.loader import SafeLoader

class YOLO_Pred():
    def __init__(self, onnx_model, data_yaml):
        # Load class names and number of classes from the YAML file
        with open(data_yaml, mode='r') as f:
            data_yaml = yaml.load(f, Loader=SafeLoader)
        
        self.labels = data_yaml['names']
        self.nc = data_yaml['nc']
        
        # Generate random colors for each class
        self.colors = self.generate_colors(self.nc)
        
        # Load YOLO model
        self.yolo = cv2.dnn.readNetFromONNX(onnx_model)
        self.yolo.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
        self.yolo.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)
    
    def prediction(self, image):
        row, col, d = image.shape
        
        # Convert the image to square shape (to match YOLO input requirements)
        max_rc = max(row, col)
        input_image = np.zeros((max_rc, max_rc, 3), dtype=np.uint8)
        input_image[0:row, 0:col] = image
        
        # Prepare input blob for YOLO model
        INPUT_WH_YOLO = 640
        blob = cv2.dnn.blobFromImage(input_image, 1/255, (INPUT_WH_YOLO, INPUT_WH_YOLO), swapRB=True, crop=False)
        self.yolo.setInput(blob)
        preds = self.yolo.forward()
        
        # Extract predictions and apply Non-Maximum Suppression (NMS)
        detections = preds[0]
        boxes, confidences, classes = [], [], []
        
        image_h, image_w = input_image.shape[:2]
        x_factor = image_w / INPUT_WH_YOLO
        y_factor = image_h / INPUT_WH_YOLO
        
        for i in range(len(detections)):
            row = detections[i]
            confidence = row[4]
            if confidence > 0.4:  # Confidence threshold
                class_score = row[5:].max()
                class_id = row[5:].argmax()
                
                if class_score > 0.25:  # Class score threshold
                    cx, cy, w, h = row[0:4]
                    left = int((cx - 0.5 * w) * x_factor)
                    top = int((cy - 0.5 * h) * y_factor)
                    width = int(w * x_factor)
                    height = int(h * y_factor)
                    
                    # Clamp bounding box to fit within the image dimensions
                    left = max(0, left)
                    top = max(0, top)
                    width = min(width, image_w - left)
                    height = min(height, image_h - top)
                    
                    box = np.array([left, top, width, height])
                    
                    # Append detected objects
                    confidences.append(float(confidence))
                    boxes.append(box)
                    classes.append(class_id)
        
        # Perform Non-Maximum Suppression (NMS)
        boxes_np = np.array(boxes).tolist()
        confidences_np = np.array(confidences).tolist()
        
        index = cv2.dnn.NMSBoxes(boxes_np, confidences_np, 0.25, 0.45)
        if len(index) > 0:
            index = index.flatten()
            
            # Draw bounding boxes and labels for detected objects
            for ind in index:
                x, y, w, h = boxes_np[ind]
                bb_conf = int(confidences_np[ind] * 100)
                class_id = classes[ind]
                class_name = self.labels[class_id]
                colors = self.colors[class_id]
                text = f'{class_name}: {bb_conf}%'
                
                # Adjust the text size and label background
                text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 1)[0]  # Reduce text size
                text_w, text_h = text_size[0], text_size[1]
                label_y = max(0, y - text_h - 10)  # Ensure the label doesn't go off the top edge
                
                # Draw bounding box
                cv2.rectangle(image, (x, y), (x + w, y + h), colors, 1)  # Thinner bounding box
                # Draw label background
                cv2.rectangle(image, (x, label_y), (x + min(w, text_w), label_y + text_h + 5), colors, -1)
                # Draw label text
                cv2.putText(image, text, (x, label_y + text_h), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1)  # Smaller text
    
        return image
    
    def generate_colors(self, nc):
        # Generate unique colors for each class
        np.random.seed(42)
        return np.random.randint(100, 255, size=(nc, 3)).tolist()

# Code to perform live YOLO prediction on webcam feed
def live_prediction():
    # Initialize YOLO model with ONNX model path and data.yaml file
    yolo = YOLO_Pred('./Model/weights/best.onnx', 'data.yaml')

    # Start video capture from the webcam
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Error: Could not open webcam.")
        exit()

    # Set full-screen mode for display
    cv2.namedWindow('Live Prediction', cv2.WND_PROP_FULLSCREEN)
    cv2.setWindowProperty('Live Prediction', cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

    # Loop to capture frames from the webcam
    while True:
        # Capture frame-by-frame from the webcam
        ret, frame = cap.read()

        if not ret:
            print("Error: Failed to capture frame.")
            break

        # Perform YOLO prediction on the current frame
        img_pred = yolo.prediction(frame)

        # Display the prediction results
        cv2.imshow('Live Prediction', img_pred)

        # Break the loop when 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release the webcam and close all windows
    cap.release()
    cv2.destroyAllWindows()

# Run the live prediction function
if __name__ == "__main__":
    live_prediction()

# %%
import cv2
import numpy as np
import yaml
from yaml.loader import SafeLoader

class YOLO_Pred():
    def __init__(self, onnx_model, data_yaml):
        with open(data_yaml, mode='r') as f:
            data_yaml = yaml.load(f, Loader=SafeLoader)

        self.labels = data_yaml['names']
        self.nc = data_yaml['nc']
        self.colors = self.generate_colors(self.nc)
        self.yolo = cv2.dnn.readNetFromONNX(onnx_model)
        self.yolo.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
        self.yolo.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)

    def prediction(self, image):
        row, col, d = image.shape
        max_rc = max(row, col)
        input_image = np.zeros((max_rc, max_rc, 3), dtype=np.uint8)
        input_image[0:row, 0:col] = image
        
        INPUT_WH_YOLO = 640
        blob = cv2.dnn.blobFromImage(input_image, 1/255, (INPUT_WH_YOLO, INPUT_WH_YOLO), swapRB=True, crop=False)
        self.yolo.setInput(blob)
        preds = self.yolo.forward()

        detections = preds[0]
        boxes, confidences, classes = [], [], []
        
        image_h, image_w = input_image.shape[:2]
        x_factor = image_w / INPUT_WH_YOLO
        y_factor = image_h / INPUT_WH_YOLO

        for i in range(len(detections)):
            row = detections[i]
            confidence = row[4]
            if confidence > 0.3:  # Lowered confidence threshold to capture more detections
                class_score = row[5:].max()
                class_id = row[5:].argmax()

                if class_score > 0.25:  # Class score threshold
                    cx, cy, w, h = row[0:4]

                    # Scale down the bounding box
                    scale_factor = 0.5  # Adjust this value for size reduction
                    w *= scale_factor
                    h *= scale_factor
                    
                    left = int((cx - 0.5 * w) * x_factor)
                    top = int((cy - 0.5 * h) * y_factor)
                    width = int(w * x_factor)
                    height = int(h * y_factor)

                    # Adjust bounding box size with padding
                    padding = 5
                    left = max(0, left + padding)
                    top = max(0, top + padding)
                    width = min(width - 2 * padding, image_w - left)
                    height = min(height - 2 * padding, image_h - top)

                    box = np.array([left, top, width, height])
                    confidences.append(float(confidence))
                    boxes.append(box)
                    classes.append(class_id)

        # Apply Non-Maximum Suppression (NMS)
        boxes_np = np.array(boxes).tolist()
        confidences_np = np.array(confidences).tolist()

        nms_threshold = 0.4  # Adjust NMS threshold to allow more detections
        index = cv2.dnn.NMSBoxes(boxes_np, confidences_np, 0.3, nms_threshold)

        if len(index) > 0:
            index = index.flatten()
            for ind in index:
                x, y, w, h = boxes_np[ind]
                class_id = classes[ind]
                bb_conf = int(confidences_np[ind] * 100)
                class_name = self.labels[class_id]
                colors = self.colors[class_id]
                text = f'{class_name}: {bb_conf}%'

                # Adjust text size and label background
                text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_PLAIN, 0.5, 1)[0]
                text_w, text_h = text_size[0], text_size[1]
                label_y = max(0, y - text_h - 10)

                # Draw bounding box
                cv2.rectangle(image, (x, y), (x + w, y + h), colors, 2)
                # Draw label background
                cv2.rectangle(image, (x, label_y), (x + min(w, text_w), label_y + text_h + 5), colors, -1)
                # Draw label text
                cv2.putText(image, text, (x, label_y + text_h), cv2.FONT_HERSHEY_PLAIN, 0.5, (0, 0, 0), 1)

        return image

    def generate_colors(self, nc):
        np.random.seed(42)
        return np.random.randint(100, 255, size=(nc, 3)).tolist()

def live_prediction():
    yolo = YOLO_Pred('./Model/weights/best.onnx', 'data.yaml')
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Error: Could not open webcam.")
        exit()

    # Set full-screen mode for display
    cv2.namedWindow('Live Prediction', cv2.WND_PROP_FULLSCREEN)
    cv2.setWindowProperty('Live Prediction', cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

    while True:
        ret, frame = cap.read()

        if not ret:
            print("Error: Failed to capture frame.")
            break

        img_pred = yolo.prediction(frame)
        cv2.imshow('Live Prediction', img_pred)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    live_prediction()

# %%
import cv2
import numpy as np
import yaml
from yaml.loader import SafeLoader

class YOLO_Pred():
    def __init__(self, onnx_model, data_yaml):
        with open(data_yaml, mode='r') as f:
            data_yaml = yaml.load(f, Loader=SafeLoader)

        self.labels = data_yaml['names']
        self.nc = data_yaml['nc']
        self.colors = self.generate_colors(self.nc)
        self.yolo = cv2.dnn.readNetFromONNX(onnx_model)
        self.yolo.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
        self.yolo.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)

    def prediction(self, image):
        row, col, d = image.shape
        max_rc = max(row, col)
        input_image = np.zeros((max_rc, max_rc, 3), dtype=np.uint8)
        input_image[0:row, 0:col] = image
        
        INPUT_WH_YOLO = 640
        blob = cv2.dnn.blobFromImage(input_image, 1/255, (INPUT_WH_YOLO, INPUT_WH_YOLO), swapRB=True, crop=False)
        self.yolo.setInput(blob)
        preds = self.yolo.forward()

        detections = preds[0]
        boxes, confidences, classes = [], [], []
        
        image_h, image_w = input_image.shape[:2]
        x_factor = image_w / INPUT_WH_YOLO
        y_factor = image_h / INPUT_WH_YOLO

        # Dictionary to count detected products
        product_count = {}

        for i in range(len(detections)):
            row = detections[i]
            confidence = row[4]
            if confidence > 0.3:  # Lowered confidence threshold to capture more detections
                class_score = row[5:].max()
                class_id = row[5:].argmax()

                if class_score > 0.25:  # Class score threshold
                    cx, cy, w, h = row[0:4]

                    # Scale down the bounding box
                    scale_factor = 0.5  # Adjust this value for size reduction
                    w *= scale_factor
                    h *= scale_factor
                    
                    left = int((cx - 0.5 * w) * x_factor)
                    top = int((cy - 0.5 * h) * y_factor)
                    width = int(w * x_factor)
                    height = int(h * y_factor)

                    # Adjust bounding box size with padding
                    padding = 5
                    left = max(0, left + padding)
                    top = max(0, top + padding)
                    width = min(width - 2 * padding, image_w - left)
                    height = min(height - 2 * padding, image_h - top)

                    box = np.array([left, top, width, height])
                    confidences.append(float(confidence))
                    boxes.append(box)
                    classes.append(class_id)

                    # Update product count
                    class_name = self.labels[class_id]
                    product_count[class_name] = product_count.get(class_name, 0) + 1

        # Apply Non-Maximum Suppression (NMS)
        boxes_np = np.array(boxes).tolist()
        confidences_np = np.array(confidences).tolist()

        nms_threshold = 0.4  # Adjust NMS threshold to allow more detections
        index = cv2.dnn.NMSBoxes(boxes_np, confidences_np, 0.3, nms_threshold)

        if len(index) > 0:
            index = index.flatten()
            for ind in index:
                x, y, w, h = boxes_np[ind]
                class_id = classes[ind]
                bb_conf = int(confidences_np[ind] * 100)
                class_name = self.labels[class_id]
                colors = self.colors[class_id]
                text = f'{class_name}: {bb_conf}%'

                # Adjust text size and label background
                text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_PLAIN, 0.5, 1)[0]
                text_w, text_h = text_size[0], text_size[1]
                label_y = max(0, y - text_h - 10)

                # Draw bounding box
                cv2.rectangle(image, (x, y), (x + w, y + h), colors, 2)
                # Draw label background
                cv2.rectangle(image, (x, label_y), (x + min(w, text_w), label_y + text_h + 5), colors, -1)
                # Draw label text
                cv2.putText(image, text, (x, label_y + text_h), cv2.FONT_HERSHEY_PLAIN, 0.5, (0, 0, 0), 1)

        # Display product count in the top left corner of the screen
        for i, (product, count) in enumerate(product_count.items()):
            text = f'{product}: {count}'
            cv2.putText(image, text, (10, 30 + i * 20), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)

        return image

    def generate_colors(self, nc):
        np.random.seed(42)
        return np.random.randint(100, 255, size=(nc, 3)).tolist()

def live_prediction():
    yolo = YOLO_Pred('./Model/weights/best.onnx', 'data.yaml')
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Error: Could not open webcam.")
        exit()

    # Set full-screen mode for display
    cv2.namedWindow('Live Prediction', cv2.WND_PROP_FULLSCREEN)
    cv2.setWindowProperty('Live Prediction', cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

    while True:
        ret, frame = cap.read()

        if not ret:
            print("Error: Failed to capture frame.")
            break

        img_pred = yolo.prediction(frame)
        cv2.imshow('Live Prediction', img_pred)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    live_prediction()

# %%
import cv2
import numpy as np
import yaml
from yaml.loader import SafeLoader

class YOLO_Pred():
    def __init__(self, onnx_model, data_yaml):
        with open(data_yaml, mode='r') as f:
            data_yaml = yaml.load(f, Loader=SafeLoader)

        self.labels = data_yaml['names']
        self.nc = data_yaml['nc']
        self.colors = self.generate_colors(self.nc)

        # Load the YOLO ONNX model
        self.yolo = cv2.dnn.readNetFromONNX(onnx_model)
        self.yolo.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
        self.yolo.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)

    def prediction(self, image):
        # Resize the image to a square and create input blob
        input_image = self.preprocess_image(image)
        INPUT_WH_YOLO = 640

        # Convert image to a blob as expected by YOLO model
        blob = cv2.dnn.blobFromImage(input_image, 1/255, (INPUT_WH_YOLO, INPUT_WH_YOLO), swapRB=True, crop=False)
        self.yolo.setInput(blob)

        # Forward pass through the network
        preds = self.yolo.forward()

        # Check if the model returned any predictions
        if preds is None or len(preds) == 0:
            print("No predictions were made by the model.")
            return image

        # Debugging output: print prediction shapes
        print(f"Predictions shape: {preds[0].shape}")

        # Process the predictions and draw boxes
        return self.process_predictions(preds[0], image)

    def preprocess_image(self, image):
        # Adjust the image to a square size
        row, col, _ = image.shape
        max_rc = max(row, col)
        input_image = np.zeros((max_rc, max_rc, 3), dtype=np.uint8)
        input_image[0:row, 0:col] = image
        return input_image

    def process_predictions(self, detections, image):
        INPUT_WH_YOLO = 640
        image_h, image_w = image.shape[:2]
        x_factor = image_w / INPUT_WH_YOLO
        y_factor = image_h / INPUT_WH_YOLO

        boxes, confidences, classes = [], [], []

        for detection in detections:
            confidence = detection[4]
            if confidence > 0.5:  # Confidence threshold
                class_scores = detection[5:]
                class_id = np.argmax(class_scores)
                class_score = class_scores[class_id]

                if class_score > 0.4:  # Class score threshold
                    cx, cy, w, h = detection[:4]

                    # Rescale bounding box coordinates
                    left = int((cx - 0.5 * w) * x_factor)
                    top = int((cy - 0.5 * h) * y_factor)
                    width = int(w * x_factor)
                    height = int(h * y_factor)

                    boxes.append([left, top, width, height])
                    confidences.append(float(confidence))
                    classes.append(class_id)

        # Apply Non-Maximum Suppression (NMS) to remove redundant boxes
        indices = cv2.dnn.NMSBoxes(boxes, confidences, score_threshold=0.5, nms_threshold=0.4)

        if len(indices) > 0:
            for i in indices.flatten():
                x, y, w, h = boxes[i]
                class_id = classes[i]
                color = self.colors[class_id]
                label = f"{self.labels[class_id]}: {int(confidences[i] * 100)}%"

                # Draw bounding box with color
                cv2.rectangle(image, (x, y), (x + w, y + h), color, 2)
                # Draw label
                cv2.putText(image, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

        return image

    def generate_colors(self, nc):
        np.random.seed(42)
        return np.random.randint(100, 255, size=(nc, 3)).tolist()


def live_prediction():
    # Replace with your ONNX model and YAML file paths
    yolo = YOLO_Pred('./Model/weights/best.onnx', './data.yaml')
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Error: Could not open webcam.")
        return

    while True:
        ret, frame = cap.read()
        if not ret:
            print("Error: Failed to capture frame.")
            break

        # Run the YOLO prediction
        img_pred = yolo.prediction(frame)

        # Display the prediction
        cv2.imshow('YOLO Prediction', img_pred)

        # Exit loop on 'q' key press
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()


if __name__ == "__main__":
    live_prediction()
# Out:
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)
# Predictions shape: (25200, 13)

# %%
import cv2
import numpy as np
import yaml
from yaml.loader import SafeLoader

class YOLO_Pred():
    def __init__(self, onnx_model, data_yaml):
        with open(data_yaml, mode='r') as f:
            data_yaml = yaml.load(f, Loader=SafeLoader)

        self.labels = data_yaml['names']
        self.nc = data_yaml['nc']
        self.colors = self.generate_colors(self.nc)

        # Load the YOLO ONNX model
        self.yolo = cv2.dnn.readNetFromONNX(onnx_model)
        self.yolo.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
        self.yolo.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)

    def prediction(self, image):
        # Resize the image to a square and create input blob
        input_image = self.preprocess_image(image)
        INPUT_WH_YOLO = 640

        # Convert image to a blob as expected by YOLO model
        blob = cv2.dnn.blobFromImage(input_image, 1/255, (INPUT_WH_YOLO, INPUT_WH_YOLO), swapRB=True, crop=False)
        self.yolo.setInput(blob)

        # Forward pass through the network
        preds = self.yolo.forward()

        # Check if the model returned any predictions
        if preds is None or len(preds) == 0:
            print("No predictions were made by the model.")
            return image

        # Debugging output: print prediction shapes
        print(f"Predictions shape: {preds[0].shape}")

        # Process the predictions and draw boxes
        return self.process_predictions(preds[0], image)

    def preprocess_image(self, image):
        # Adjust the image to a square size
        row, col, _ = image.shape
        max_rc = max(row, col)
        input_image = np.zeros((max_rc, max_rc, 3), dtype=np.uint8)
        input_image[0:row, 0:col] = image
        return input_image

    def process_predictions(self, detections, image):
        INPUT_WH_YOLO = 640
        image_h, image_w = image.shape[:2]
        x_factor = image_w / INPUT_WH_YOLO
        y_factor = image_h / INPUT_WH_YOLO

        boxes, confidences, classes = [], [], []

        for detection in detections:
            confidence = detection[4]
            if confidence > 0.5:  # Confidence threshold
                class_scores = detection[5:]
                class_id = np.argmax(class_scores)
                class_score = class_scores[class_id]

                if class_score > 0.4:  # Class score threshold
                    cx, cy, w, h = detection[:4]

                    # Rescale bounding box coordinates
                    left = int((cx - 0.5 * w) * x_factor)
                    top = int((cy - 0.5 * h) * y_factor)
                    width = int(w * x_factor)
                    height = int(h * y_factor)

                    boxes.append([left, top, width, height])
                    confidences.append(float(confidence))
                    classes.append(class_id)

        # Apply Non-Maximum Suppression (NMS) to remove redundant boxes
        indices = cv2.dnn.NMSBoxes(boxes, confidences, score_threshold=0.5, nms_threshold=0.4)

        if len(indices) > 0:
            for i in indices.flatten():
                x, y, w, h = boxes[i]
                class_id = classes[i]
                color = self.colors[class_id]
                label = f"{self.labels[class_id]}: {int(confidences[i] * 100)}%"

                # Draw bounding box with color
                cv2.rectangle(image, (x, y), (x + w, y + h), color, 2)
                # Draw label
                cv2.putText(image, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

        return image

    def generate_colors(self, nc):
        np.random.seed(42)
        return np.random.randint(100, 255, size=(nc, 3)).tolist()


def predict_from_image(image_path):
    # Replace with your ONNX model and YAML file paths
    yolo = YOLO_Pred('./Model/weights/best.onnx', './data.yaml')
    
    # Load the image from the provided path
    image = cv2.imread(image_path)

    if image is None:
        print(f"Error: Could not load image at {image_path}")
        return

    # Run the YOLO prediction
    img_pred = yolo.prediction(image)

    # Display the prediction
    cv2.imshow('YOLO Prediction', img_pred)

    # Save the output image with predictions
    output_path = "output_prediction.jpg"
    cv2.imwrite(output_path, img_pred)
    print(f"Prediction saved to {output_path}")

    # Wait for a key press to close the image window
    cv2.waitKey(0)
    cv2.destroyAllWindows()


if __name__ == "__main__":
    # Replace with the path to the image file you want to process
    image_path = "sam2.jpg"
    predict_from_image(image_path)
# Out:
# Predictions shape: (25200, 13)
# Prediction saved to output_prediction.jpg

# %%
import cv2
import numpy as np
import yaml
from yaml.loader import SafeLoader

class YOLO_Pred():
    def __init__(self, onnx_model, data_yaml):
        with open(data_yaml, mode='r') as f:
            data_yaml = yaml.load(f, Loader=SafeLoader)

        self.labels = data_yaml['names']
        self.nc = data_yaml['nc']
        self.colors = self.generate_colors(self.nc)

        # Load the YOLO ONNX model
        self.yolo = cv2.dnn.readNetFromONNX(onnx_model)
        self.yolo.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
        self.yolo.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)

    def prediction(self, image):
        # Resize the image to a square and create input blob
        input_image = self.preprocess_image(image)
        INPUT_WH_YOLO = 640

        # Convert image to a blob as expected by YOLO model
        blob = cv2.dnn.blobFromImage(input_image, 1/255, (INPUT_WH_YOLO, INPUT_WH_YOLO), swapRB=True, crop=False)
        self.yolo.setInput(blob)

        # Forward pass through the network
        preds = self.yolo.forward()

        # Check if the model returned any predictions
        if preds is None or len(preds) == 0:
            print("No predictions were made by the model.")
            return image, 0

        # Debugging output: print prediction shapes
        print(f"Predictions shape: {preds[0].shape}")

        # Process the predictions and draw boxes
        return self.process_predictions(preds[0], image)

    def preprocess_image(self, image):
        # Adjust the image to a square size
        row, col, _ = image.shape
        max_rc = max(row, col)
        input_image = np.zeros((max_rc, max_rc, 3), dtype=np.uint8)
        input_image[0:row, 0:col] = image
        return input_image

    def process_predictions(self, detections, image):
        INPUT_WH_YOLO = 640
        image_h, image_w = image.shape[:2]
        x_factor = image_w / INPUT_WH_YOLO
        y_factor = image_h / INPUT_WH_YOLO

        boxes, confidences, classes = [], [], []
        detected_packs = 0  # Counter for detected objects (packs)

        for detection in detections:
            confidence = detection[4]
            if confidence > 0.5:  # Confidence threshold
                class_scores = detection[5:]
                class_id = np.argmax(class_scores)
                class_score = class_scores[class_id]

                if class_score > 0.4:  # Class score threshold
                    cx, cy, w, h = detection[:4]

                    # Rescale bounding box coordinates
                    left = int((cx - 0.5 * w) * x_factor)
                    top = int((cy - 0.5 * h) * y_factor)
                    width = int(w * x_factor)
                    height = int(h * y_factor)

                    boxes.append([left, top, width, height])
                    confidences.append(float(confidence))
                    classes.append(class_id)

                    detected_packs += 1  # Increment the counter for each detected pack

        # Apply Non-Maximum Suppression (NMS) to remove redundant boxes
        indices = cv2.dnn.NMSBoxes(boxes, confidences, score_threshold=0.5, nms_threshold=0.4)

        if len(indices) > 0:
            for i in indices.flatten():
                x, y, w, h = boxes[i]
                class_id = classes[i]
                color = self.colors[class_id]
                label = f"{self.labels[class_id]}: {int(confidences[i] * 100)}%"

                # Draw bounding box with color
                cv2.rectangle(image, (x, y), (x + w, y + h), color, 2)
                # Draw label
                cv2.putText(image, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

        return image, detected_packs

    def generate_colors(self, nc):
        np.random.seed(42)
        return np.random.randint(100, 255, size=(nc, 3)).tolist()


def predict_and_count_packs(image_path):
    # Replace with your ONNX model and YAML file paths
    yolo = YOLO_Pred('./Model/weights/best.onnx', './data.yaml')
    
    # Load the image from the provided path
    image = cv2.imread(image_path)

    if image is None:
        print(f"Error: Could not load image at {image_path}")
        return

    # Run the YOLO prediction and count the detected packs
    img_pred, pack_count = yolo.prediction(image)

    # Display the prediction and pack count
    cv2.putText(img_pred, f"Detected Packs: {pack_count}", (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.imshow('YOLO Prediction', img_pred)

    # Save the output image with predictions and pack count
    output_path = "output_with_count.jpg"
    cv2.imwrite(output_path, img_pred)
    print(f"Prediction saved to {output_path}, Packs Count: {pack_count}")

    # Wait for a key press to close the image window
    cv2.waitKey(0)
    cv2.destroyAllWindows()


if __name__ == "__main__":
    # Replace with the path to the image file you want to process
    image_path = "pack2.jpg"
    predict_and_count_packs(image_path)
# Out:
# Predictions shape: (25200, 13)
# Prediction saved to output_with_count.jpg, Packs Count: 31

# %%
import cv2
import numpy as np
import yaml
from yaml.loader import SafeLoader
import time

class YOLO_Pred():
    def __init__(self, onnx_model, data_yaml):
        with open(data_yaml, mode='r') as f:
            data_yaml = yaml.load(f, Loader=SafeLoader)

        self.labels = data_yaml['names']
        self.nc = data_yaml['nc']
        self.colors = self.generate_colors(self.nc)
        self.yolo = cv2.dnn.readNetFromONNX(onnx_model)
        self.yolo.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
        self.yolo.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)
        self.object_tracker = {}

    def prediction(self, image):
        row, col, d = image.shape
        max_rc = max(row, col)
        input_image = np.zeros((max_rc, max_rc, 3), dtype=np.uint8)
        input_image[0:row, 0:col] = image
        
        INPUT_WH_YOLO = 640
        blob = cv2.dnn.blobFromImage(input_image, 1/255, (INPUT_WH_YOLO, INPUT_WH_YOLO), swapRB=True, crop=False)
        self.yolo.setInput(blob)
        preds = self.yolo.forward()

        detections = preds[0]
        boxes, confidences, classes = [], [], []
        
        image_h, image_w = input_image.shape[:2]
        x_factor = image_w / INPUT_WH_YOLO
        y_factor = image_h / INPUT_WH_YOLO

        object_count = 0

        for i in range(len(detections)):
            row = detections[i]
            confidence = row[4]
            if confidence > 0.3:
                class_score = row[5:].max()
                class_id = row[5:].argmax()

                if class_score > 0.25:
                    cx, cy, w, h = row[0:4]
                    left = int((cx - 0.5 * w) * x_factor)
                    top = int((cy - 0.5 * h) * y_factor)
                    width = int(w * x_factor)
                    height = int(h * y_factor)

                    box = np.array([left, top, width, height])
                    confidences.append(float(confidence))
                    boxes.append(box)
                    classes.append(class_id)

                    # Unique object ID to avoid double counting
                    object_id = f"{left}_{top}_{width}_{height}"
                    if object_id not in self.object_tracker:
                        self.object_tracker[object_id] = True
                        object_count += 1

        return object_count

    def generate_colors(self, nc):
        np.random.seed(42)
        return np.random.randint(100, 255, size=(nc, 3)).tolist()

def live_prediction():
    yolo = YOLO_Pred('./Model/weights/best.onnx', 'data.yaml')
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Error: Could not open webcam.")
        exit()

    start_time = time.time()
    total_count = 0

    while time.time() - start_time < 10:  # Run the detection for 10 seconds
        ret, frame = cap.read()

        if not ret:
            print("Error: Failed to capture frame.")
            break

        count = yolo.prediction(frame)
        total_count += count

    cap.release()

    # Save the count to a Notepad file
    with open("product_count.txt", "w") as f:
        f.write(f"Total Products Detected: {total_count}")

    print("Product count written to product_count.txt")
    # Automatically open the Notepad with the count
    import os
    os.system("notepad.exe product_count.txt")

if __name__ == "__main__":
    live_prediction()
# Out:
# Product count written to product_count.txt

# %%
import cv2
import numpy as np
import yaml
from yaml.loader import SafeLoader
import time
import os

class YOLO_Pred():
    def __init__(self, onnx_model, data_yaml):
        with open(data_yaml, mode='r') as f:
            data_yaml = yaml.load(f, Loader=SafeLoader)

        self.labels = data_yaml['names']
        self.nc = data_yaml['nc']
        self.colors = self.generate_colors(self.nc)
        self.yolo = cv2.dnn.readNetFromONNX(onnx_model)
        self.yolo.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
        self.yolo.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)
        self.detected_objects = set()  # To track detected objects and avoid double counting

    def prediction(self, image):
        row, col, d = image.shape
        max_rc = max(row, col)
        input_image = np.zeros((max_rc, max_rc, 3), dtype=np.uint8)
        input_image[0:row, 0:col] = image
        
        INPUT_WH_YOLO = 640
        blob = cv2.dnn.blobFromImage(input_image, 1/255, (INPUT_WH_YOLO, INPUT_WH_YOLO), swapRB=True, crop=False)
        self.yolo.setInput(blob)
        preds = self.yolo.forward()

        detections = preds[0]
        boxes, confidences, classes = [], [], []
        
        image_h, image_w = input_image.shape[:2]
        x_factor = image_w / INPUT_WH_YOLO
        y_factor = image_h / INPUT_WH_YOLO

        object_count = 0

        for i in range(len(detections)):
            row = detections[i]
            confidence = row[4]
            if confidence > 0.3:  # Confidence threshold
                class_score = row[5:].max()
                class_id = row[5:].argmax()

                if class_score > 0.25:  # Class score threshold
                    cx, cy, w, h = row[0:4]
                    left = int((cx - 0.5 * w) * x_factor)
                    top = int((cy - 0.5 * h) * y_factor)
                    width = int(w * x_factor)
                    height = int(h * y_factor)

                    box = np.array([left, top, width, height])
                    confidences.append(float(confidence))
                    boxes.append(box)
                    classes.append(class_id)

                    # Create a unique ID for each object using bounding box coordinates
                    object_id = f"{left}_{top}_{width}_{height}"

                    # Avoid counting the same object more than once
                    if object_id not in self.detected_objects:
                        self.detected_objects.add(object_id)
                        object_count += 1

        return object_count

    def generate_colors(self, nc):
        np.random.seed(42)
        return np.random.randint(100, 255, size=(nc, 3)).tolist()

def live_prediction():
    yolo = YOLO_Pred('./Model/weights/best.onnx', 'data.yaml')
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Error: Could not open webcam.")
        exit()

    start_time = time.time()
    total_count = 0

    while time.time() - start_time < 10:  # Run the detection for 10 seconds
        ret, frame = cap.read()

        if not ret:
            print("Error: Failed to capture frame.")
            break

        count = yolo.prediction(frame)
        total_count += count

        # Display the frame (optional, for visual confirmation)
        cv2.imshow('Live Prediction', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

    # Save the count to a Notepad file
    with open("product_count.txt", "w") as f:
        f.write(f"Total Products Detected: {total_count}")

    print(f"Product count written to product_count.txt: {total_count}")

    # Automatically open the Notepad with the count
    os.system("notepad.exe product_count.txt")

if __name__ == "__main__":
    live_prediction()
# Out:
# Product count written to product_count.txt: 6

# %%
import cv2
import numpy as np
import yaml
from yaml.loader import SafeLoader
import time
import os

class YOLO_Pred():
    def __init__(self, onnx_model, data_yaml):
        with open(data_yaml, mode='r') as f:
            data_yaml = yaml.load(f, Loader=SafeLoader)

        self.labels = data_yaml['names']  # List of product names (classes)
        self.nc = data_yaml['nc']  # Number of classes
        self.colors = self.generate_colors(self.nc)
        self.yolo = cv2.dnn.readNetFromONNX(onnx_model)
        self.yolo.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
        self.yolo.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)
        self.detected_objects = set()

    def prediction(self, image):
        row, col, d = image.shape
        max_rc = max(row, col)
        input_image = np.zeros((max_rc, max_rc, 3), dtype=np.uint8)
        input_image[0:row, 0:col] = image
        
        INPUT_WH_YOLO = 640
        blob = cv2.dnn.blobFromImage(input_image, 1/255, (INPUT_WH_YOLO, INPUT_WH_YOLO), swapRB=True, crop=False)
        self.yolo.setInput(blob)
        preds = self.yolo.forward()

        detections = preds[0]
        boxes, confidences, classes = [], [], []
        
        image_h, image_w = input_image.shape[:2]
        x_factor = image_w / INPUT_WH_YOLO
        y_factor = image_h / INPUT_WH_YOLO

        product_counts = {label: 0 for label in self.labels}  # Initialize separate count for each product

        for i in range(len(detections)):
            row = detections[i]
            confidence = row[4]
            if confidence > 0.3:  # Confidence threshold
                class_score = row[5:].max()
                class_id = row[5:].argmax()

                if class_score > 0.25:  # Class score threshold
                    cx, cy, w, h = row[0:4]
                    left = int((cx - 0.5 * w) * x_factor)
                    top = int((cy - 0.5 * h) * y_factor)
                    width = int(w * x_factor)
                    height = int(h * y_factor)

                    box = np.array([left, top, width, height])
                    confidences.append(float(confidence))
                    boxes.append(box)
                    classes.append(class_id)

                    # Create a unique ID for each object using bounding box coordinates
                    object_id = f"{left}_{top}_{width}_{height}"

                    # Avoid counting the same object more than once
                    if object_id not in self.detected_objects:
                        self.detected_objects.add(object_id)
                        # Increase count for the corresponding product class
                        product_counts[self.labels[class_id]] += 1

        return product_counts  # Return the count of each product

    def generate_colors(self, nc):
        np.random.seed(42)
        return np.random.randint(100, 255, size=(nc, 3)).tolist()

def live_prediction():
    yolo = YOLO_Pred('./Model/weights/best.onnx', 'data.yaml')
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Error: Could not open webcam.")
        exit()

    start_time = time.time()
    overall_product_counts = {label: 0 for label in yolo.labels}  # Total counts for all products

    while time.time() - start_time < 10:  # Run detection for 10 seconds
        ret, frame = cap.read()

        if not ret:
            print("Error: Failed to capture frame.")
            break

        product_counts = yolo.prediction(frame)

        # Update overall count for each product
        for label in yolo.labels:
            overall_product_counts[label] += product_counts[label]

        # Display the frame (optional, for visual confirmation)
        cv2.imshow('Live Prediction', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

    # Write separate product counts to a Notepad file
    with open("product_count.txt", "w") as f:
        for label, count in overall_product_counts.items():
            f.write(f"{label}: {count} detected\n")

    print(f"Product count written to product_count.txt")

    # Automatically open the Notepad with the counts
    os.system("notepad.exe product_count.txt")

if __name__ == "__main__":
    live_prediction()
# Out:
# Product count written to product_count.txt

# %%
import cv2
import numpy as np
import yaml
from yaml.loader import SafeLoader
import time
import os

class YOLO_Pred():
    def __init__(self, onnx_model, data_yaml):
        with open(data_yaml, mode='r') as f:
            data_yaml = yaml.load(f, Loader=SafeLoader)

        self.labels = data_yaml['names']  # List of product names (classes)
        self.nc = data_yaml['nc']  # Number of classes
        self.colors = self.generate_colors(self.nc)
        self.yolo = cv2.dnn.readNetFromONNX(onnx_model)
        self.yolo.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
        self.yolo.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)
        self.detected_objects = set()

    def prediction(self, image):
        row, col, d = image.shape
        max_rc = max(row, col)
        input_image = np.zeros((max_rc, max_rc, 3), dtype=np.uint8)
        input_image[0:row, 0:col] = image
        
        INPUT_WH_YOLO = 640
        blob = cv2.dnn.blobFromImage(input_image, 1/255, (INPUT_WH_YOLO, INPUT_WH_YOLO), swapRB=True, crop=False)
        self.yolo.setInput(blob)
        preds = self.yolo.forward()

        detections = preds[0]
        boxes, confidences, classes = [], [], []
        
        image_h, image_w = input_image.shape[:2]
        x_factor = image_w / INPUT_WH_YOLO
        y_factor = image_h / INPUT_WH_YOLO

        product_counts = {label: 0 for label in self.labels}  # Initialize separate count for each product

        for i in range(len(detections)):
            row = detections[i]
            confidence = row[4]
            if confidence > 0.3:  # Confidence threshold
                class_score = row[5:].max()
                class_id = row[5:].argmax()

                if class_score > 0.25:  # Class score threshold
                    cx, cy, w, h = row[0:4]
                    left = int((cx - 0.5 * w) * x_factor)
                    top = int((cy - 0.5 * h) * y_factor)
                    width = int(w * x_factor)
                    height = int(h * y_factor)

                    box = np.array([left, top, width, height])
                    confidences.append(float(confidence))
                    boxes.append(box)
                    classes.append(class_id)

                    # Create a unique ID for each object using bounding box coordinates
                    object_id = f"{left}_{top}_{width}_{height}"

                    # Avoid counting the same object more than once
                    if object_id not in self.detected_objects:
                        self.detected_objects.add(object_id)
                        # Increase count for the corresponding product class
                        product_counts[self.labels[class_id]] += 1

        return product_counts  # Return the count of each product

    def generate_colors(self, nc):
        np.random.seed(42)
        return np.random.randint(100, 255, size=(nc, 3)).tolist()

def live_prediction():
    yolo = YOLO_Pred('./Model/weights/best.onnx', 'data.yaml')
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Error: Could not open webcam.")
        exit()

    start_time = time.time()
    overall_product_counts = {label: 0 for label in yolo.labels}  # Total counts for all products

    # Set default values for specific products
    default_products = ["Garam Masala", "Chilli Powder", "Turmeric Powder"]
    for product in default_products:
        if product in overall_product_counts:
            overall_product_counts[product] = 1  # Set default value of 1

    while time.time() - start_time < 10:  # Run detection for 10 seconds
        ret, frame = cap.read()

        if not ret:
            print("Error: Failed to capture frame.")
            break

        product_counts = yolo.prediction(frame)

        # Update overall count for each product
        for label in yolo.labels:
            overall_product_counts[label] += product_counts[label]

        # Display the frame (optional, for visual confirmation)
        cv2.imshow('Live Prediction', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

    # Write separate product counts to a Notepad file
    with open("product_count.txt", "w") as f:
        for label, count in overall_product_counts.items():
            f.write(f"{label}: {count} detected\n")

    print(f"Product count written to product_count.txt")

    # Automatically open the Notepad with the counts
    os.system("notepad.exe product_count.txt")

if __name__ == "__main__":
    live_prediction()
# Out:
# Product count written to product_count.txt

# %%
import cv2
import numpy as np
import yaml
from yaml.loader import SafeLoader
import time
import os

class YOLO_Pred():
    def __init__(self, onnx_model, data_yaml):
        with open(data_yaml, mode='r') as f:
            data_yaml = yaml.load(f, Loader=SafeLoader)

        self.labels = data_yaml['names']  # List of product names (classes)
        self.nc = data_yaml['nc']  # Number of classes
        self.colors = self.generate_colors(self.nc)
        self.yolo = cv2.dnn.readNetFromONNX(onnx_model)
        self.yolo.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
        self.yolo.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)
        self.detected_objects = set()

    def prediction(self, image):
        row, col, d = image.shape
        max_rc = max(row, col)
        input_image = np.zeros((max_rc, max_rc, 3), dtype=np.uint8)
        input_image[0:row, 0:col] = image
        
        INPUT_WH_YOLO = 640
        blob = cv2.dnn.blobFromImage(input_image, 1/255, (INPUT_WH_YOLO, INPUT_WH_YOLO), swapRB=True, crop=False)
        self.yolo.setInput(blob)
        preds = self.yolo.forward()

        detections = preds[0]
        boxes, confidences, classes = [], [], []
        
        image_h, image_w = input_image.shape[:2]
        x_factor = image_w / INPUT_WH_YOLO
        y_factor = image_h / INPUT_WH_YOLO

        product_counts = {label: 0 for label in self.labels}  # Initialize separate count for each product

        for i in range(len(detections)):
            row = detections[i]
            confidence = row[4]
            if confidence > 0.3:  # Confidence threshold
                class_score = row[5:].max()
                class_id = row[5:].argmax()

                if class_score > 0.25:  # Class score threshold
                    cx, cy, w, h = row[0:4]
                    left = int((cx - 0.5 * w) * x_factor)
                    top = int((cy - 0.5 * h) * y_factor)
                    width = int(w * x_factor)
                    height = int(h * y_factor)

                    box = np.array([left, top, width, height])
                    confidences.append(float(confidence))
                    boxes.append(box)
                    classes.append(class_id)

                    # Create a unique ID for each object using bounding box coordinates
                    object_id = f"{left}_{top}_{width}_{height}"

                    # Avoid counting the same object more than once
                    if object_id not in self.detected_objects:
                        self.detected_objects.add(object_id)
                        # Increase count for the corresponding product class
                        product_counts[self.labels[class_id]] += 1

        return product_counts  # Return the count of each product

    def generate_colors(self, nc):
        np.random.seed(42)
        return np.random.randint(100, 255, size=(nc, 3)).tolist()

def live_prediction():
    yolo = YOLO_Pred('./Model/weights/best.onnx', 'data.yaml')
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Error: Could not open webcam.")
        exit()

    start_time = time.time()
    
    # Initialize overall product counts with default values
    overall_product_counts = {label: 0 for label in yolo.labels}  # Set all counts to 0
    overall_product_counts["Garam Masala"] = 1  # Set default value of 1 for Garam Masala
    overall_product_counts["Chilli Powder"] = 1  # Set default value of 1 for Chilli Powder
    overall_product_counts["Turmeric Powder"] = 1  # Set default value of 1 for Turmeric Powder

    while time.time() - start_time < 10:  # Run detection for 10 seconds
        ret, frame = cap.read()

        if not ret:
            print("Error: Failed to capture frame.")
            break

        product_counts = yolo.prediction(frame)

        # Update overall count for each product
        for label in yolo.labels:
            overall_product_counts[label] += product_counts[label]

        # Display the frame (optional, for visual confirmation)
        cv2.imshow('Live Prediction', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

    # Write separate product counts to a Notepad file
    with open("product_count.txt", "w") as f:
        for label, count in overall_product_counts.items():
            f.write(f"{label}: {count} detected\n")

    print(f"Product count written to product_count.txt")

    # Automatically open the Notepad with the counts
    os.system("notepad.exe product_count.txt")

if __name__ == "__main__":
    live_prediction()
# Out:
# Product count written to product_count.txt
